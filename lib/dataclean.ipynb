# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\krishna\Desktop\food_data_csv.csv')

# %%
data
# Out:
#            ID                                               name   Food Group  \
# 0      167512  Pillsbury Golden Layer Buttermilk Biscuits Art...  Baked Foods
# 1      167513  Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods
# 2      167514  Kraft Foods Shake N Bake Original Recipe Coati...  Baked Foods
# 3      167515      George Weston Bakeries Thomas English Muffins  Baked Foods
# 4      167516            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods
# ...       ...                                                ...          ...
# 14159  789766                 Cheese As Ingredient In Sandwiches          NaN
# 14160  789767           Breading Or Batter As Ingredient In Food          NaN
# 14161  789768            Wheat Bread As Ingredient In Sandwiches          NaN
# 14162  789769                  Sauce As Ingredient In Hamburgers          NaN
# 14163  789770               Industrial Oil As Ingredient In Food          NaN
#
# ...

# %%
df = data.drop(['Unnamed: 8'], axis=1)
df = df.dropna()
df.shape
# Out:
# (13541, 8)

# %%
df
# Out:
#            ID                                               name   Food Group  \
# 0      167512  Pillsbury Golden Layer Buttermilk Biscuits Art...  Baked Foods
# 1      167513  Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods
# 2      167514  Kraft Foods Shake N Bake Original Recipe Coati...  Baked Foods
# 3      167515      George Weston Bakeries Thomas English Muffins  Baked Foods
# 4      167516            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods
# ...       ...                                                ...          ...
# 14154  789710  Nutritional Drink Or Shake Ready-To-Drink Ligh...    Beverages
# 14155  789713  Nutritional Drink Or Shake High Protein Ready-...    Beverages
# 14156  789715  Nutritional Drink Or Shake High Protein Ready-...    Beverages
# 14157  789724  Nutritional Powder Mix (Kellogg's Special K20 ...   Baby Foods
# 14158  789764              Fluid Replacement 5% Glucose In Water    Beverages
#
# ...

# %%
try:
    df['C'] = df['Serving Description 1 (g)'].str.extract('(\d+)').astype(int)
except Exception:
    pass

# %%
df1=pd.read_csv(r'C:\Users\krishna\Desktop\lynn\lib\food_data_clean_df.csv')

# %%
df1['C'] = df1['Serving Description 1 (g)'].str.extract('(\d+)').astype(str)

# %%
df1
# Out:
#        Unnamed: 0      ID                                               name  \
# 0               1  173857                           Turkey Baloney (Bologna)
# 1               2  173889                              Post Honeycomb Cereal
# 2               3  173890                                Quaker King Vitaman
# 3               4  170865                           Dessert Topping Powdered
# 4               5  783450  Cheeseburger 1 Large Patty Plain On Bun From F...
# ...           ...     ...                                                ...
# 13521       13522  174856                     Ocean Spray Ruby Red Cranberry
# 13522       13523  174161  Water With Added Vitamins And Minerals Bottles...
# 13523       13524  171942                              Unsweetened Rice Milk
# 13524       13525  169006        Stew Pinto Bean And Hominy Badufsuki (Hopi)
# 13525       13526  174974                  Cookies Vanilla Wafers Higher Fat
#
# ...

# %%
df1['d']= df1['Serving Description 1 (g)'].replace(df1['C'].to_string,"");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-1caaaa0588c8> in <module>
# ----> 1 df1['d']= df1['Serving Description 1 (g)'].replace(df1['C'].to_string,"");
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6437             or is_list_like(to_replace)
#    6438         ):
# -> 6439             raise TypeError(
#    6440                 "Expecting 'to_replace' to be either a scalar, array-like, "
# ...

# %%
for i in range (len(df1['C'])):
    df1['C1'][i]=df1['Serving Description 1 (g)'][i].replace(df1['C'][i],"")
# Out:
# <ipython-input-73-5554351c7d8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['C1'][i]=df1['Serving Description 1 (g)'][i].replace(df1['C'][i],"")
# C:\Users\krishna\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df1
# Out:
#        Unnamed: 0      ID                                               name  \
# 0               1  173857                           Turkey Baloney (Bologna)
# 1               2  173889                              Post Honeycomb Cereal
# 2               3  173890                                Quaker King Vitaman
# 3               4  170865                           Dessert Topping Powdered
# 4               5  783450  Cheeseburger 1 Large Patty Plain On Bun From F...
# ...           ...     ...                                                ...
# 13521       13522  174856                     Ocean Spray Ruby Red Cranberry
# 13522       13523  174161  Water With Added Vitamins And Minerals Bottles...
# 13523       13524  171942                              Unsweetened Rice Milk
# 13524       13525  169006        Stew Pinto Bean And Hominy Badufsuki (Hopi)
# 13525       13526  174974                  Cookies Vanilla Wafers Higher Fat
#
# ...

# %%
df1.to_csv("lololo.csv")
